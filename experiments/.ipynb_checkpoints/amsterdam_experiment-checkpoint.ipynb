# %%
import numpy as np

import matplotlib.pyplot as plt
import igraph as ig
from pathlib import Path
import geopandas as gpd
from eptnr.datasets.dataset_loader import load_dataset
from eptnr.datasets.synthetic_datasets import SyntheticDatasets
from eptnr.rewards.egalitarian import EgalitarianTheilAndCostReward
from eptnr.constants.travel_metric import TravelMetric
from eptnr.plotting.data_exploration import plot_travel_time_histogram
from eptnr.analysis.full_problem_exploration import full_problem_exploration
import pandas as pd
from eptnr.algorithms.baselines.optimal_baseline import optimal_max_baseline
import seaborn as sns

# %% [markdown]
# # Dataset loading

# %%
graph = ig.read(Path('../eptnr_package/eptnr/datasets/amsterdam_10_2022/resulting_graph/Amsterdam_problem_graph_2022-11-05.gml'))

# %%
census = gpd.read_parquet(Path('../eptnr_package/eptnr/datasets/amsterdam_10_2022/ams_census_and_neighborhood_data_2021.parquet'),)
census["neighborhood"] = 'RC_' + census['BU_NAAM']
census['n_inh'] = census['a_inw']
census["res_centroids"] = census["res_centroid"]
census["geometry"] = census["res_centroid"]

all_w_nw_inh = census['a_w_all'] + census['a_nw_all'] + 0.0001

census["n_western"] = (census['a_inw'] * (census['a_w_all'] / all_w_nw_inh)).astype('int')
census["n_non_western"] = census['a_inw'] - census["n_western"]

census = census[["neighborhood", "n_inh", "n_western", "n_non_western", "geometry"]]

# %%
census
# Out:
#                      neighborhood  n_inh  n_western  n_non_western  \
# 0                  RC_Kop Zeedijk   1110        721            389
# 1               RC_Oude Kerk e.o.    695        466            229
# 2              RC_Burgwallen Oost   1645       1023            622
# 3                     RC_Nes e.o.    365        276             89
# 4              RC_BG-terrein e.o.    690        444            246
# ..                            ...    ...        ...            ...
# 443              RC_Gein Zuidwest   1665        201           1464
# 444             RC_Gein Noordoost   3245        943           2302
# 445              RC_Gein Zuidoost   3355        602           2753
# 446              RC_Dorp Driemond   1480        662            818
# 447  RC_Landelijk gebied Driemond    140         83             57
#
#                      geometry
# 0    POINT (4.90009 52.37552)
# 1    POINT (4.89678 52.37375)
# 2    POINT (4.89875 52.37283)
# 3    POINT (4.89423 52.37094)
# 4    POINT (4.89588 52.36999)
# ..                        ...
# 443  POINT (4.98511 52.29471)
# 444  POINT (4.99445 52.29913)
# 445  POINT (4.99021 52.29315)
# 446  POINT (5.01649 52.30562)
# 447  POINT (5.01314 52.30975)
#
# [448 rows x 5 columns]

# %%
plot_travel_time_histogram(graph, census)
# Out:
# <AxesSubplot: xlabel='value', ylabel='Count'>

# %%
total_graph_cost = sum(graph.es.select(type_ne='walk')['cost'])
total_graph_cost
# Out:
# 468865.7190800001

# %%
# What GVB needs to save (30%)
monetary_budget = total_graph_cost * 0.3
groups = None
metrics = [TravelMetric.TT]

# %% [markdown]
# # Deep MaxQ-Learning

# %%
from eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner import DeepMaxQLearner

reward = EgalitarianTheilAndCostReward(census_data=census, com_threshold=0,
                                       total_graph_cost=total_graph_cost, monetary_budget=monetary_budget,
                                       groups=groups, metrics=metrics, verbose=True)
edge_types = set(graph.es.select(type_ne='walk')['type'])
episodes = 128
batch_size = 64
replay_memory_size = 2048
target_network_update_step = 16
static_eps_steps = 64

# %%
edge_types
# Out:
# {'METRO'}

# %%
dmql = DeepMaxQLearner(
    base_graph=graph,
    reward=reward,
    edge_types=edge_types,
    episodes=episodes,
    batch_size=batch_size,
    replay_memory_size=replay_memory_size,
    target_network_update_step=target_network_update_step,
    static_eps_steps=static_eps_steps
)

# %%
max_rewards_over_episodes, epsilon_over_episodes = dmql.train(return_max_rewards_over_episodes=True,
                                                              return_epsilon_over_episodes=True, verbose=True)
# Out:
#   0%|          | 0/128 [00:00<?, ?it/s]INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18053
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10150233136462072
# 	scaled_reward=0.10150233136462072
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18052
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11451755671660928
# 	scaled_reward=0.11451755671660928
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18051
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18050
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18049
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18048
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18047
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18046
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1147783498900457
# 	scaled_reward=0.1147783498900457
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18045
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11479665342882514
# 	scaled_reward=0.11479665342882514
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18044
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11479665342882514
# 	scaled_reward=0.11479665342882514
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18043
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13549669030029118
# 	scaled_reward=0.13549669030029118
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18042
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13549669030029118
# 	scaled_reward=0.13549669030029118
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18041
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13549669030029118
# 	scaled_reward=0.13549669030029118
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18040
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13549669030029118
# 	scaled_reward=0.13549669030029118
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18039
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13497002242596504
# 	scaled_reward=0.13497002242596504
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18038
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18037
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18036
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18035
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18034
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18033
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18032
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18031
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18030
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13520782182380592
# 	scaled_reward=0.13520782182380592
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18029
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1373460436394332
# 	scaled_reward=0.1373460436394332
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18028
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15305790182033735
# 	scaled_reward=0.15305790182033735
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18027
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15305790182033735
# 	scaled_reward=0.15305790182033735
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18026
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15305790182033735
# 	scaled_reward=0.15305790182033735
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18025
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15874179347463965
# 	scaled_reward=0.15874179347463965
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18024
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15874179347463965
# 	scaled_reward=0.15874179347463965
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18023
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15874179347463965
# 	scaled_reward=0.15874179347463965
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18022
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18021
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18020
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18019
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18018
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18017
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18016
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18015
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16210451097874776
# 	scaled_reward=0.16210451097874776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18014
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16188151947507215
# 	scaled_reward=0.16188151947507215
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18013
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16188151947507215
# 	scaled_reward=0.16188151947507215
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18012
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16188151947507215
# 	scaled_reward=0.16188151947507215
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18011
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1613267662473569
# 	scaled_reward=0.1613267662473569
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18010
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15120681648456696
# 	scaled_reward=0.15120681648456696
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18009
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15120681648456696
# 	scaled_reward=0.15120681648456696
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18008
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15124395846524014
# 	scaled_reward=0.15124395846524014
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18007
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15124395846524014
# 	scaled_reward=0.15124395846524014
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18006
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15124395846524014
# 	scaled_reward=0.15124395846524014
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18005
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15124395846524014
# 	scaled_reward=0.15124395846524014
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18004
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15767936072811153
# 	scaled_reward=0.15767936072811153
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18003
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16150149492810503
# 	scaled_reward=0.16150149492810503
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18002
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.16150149492810503
# 	scaled_reward=0.16150149492810503
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18001
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15668292039699272
# 	scaled_reward=0.15668292039699272
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18000
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15668292039699272
# 	scaled_reward=0.15668292039699272
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17999
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15668292039699272
# 	scaled_reward=0.15668292039699272
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17998
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15185837802982668
# 	scaled_reward=0.15185837802982668
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17997
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15186646839228796
# 	scaled_reward=0.15186646839228796
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17996
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15186646839228796
# 	scaled_reward=0.15186646839228796
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17995
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15186646839228796
# 	scaled_reward=0.15186646839228796
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17994
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1476547660983776
# 	scaled_reward=0.1476547660983776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17993
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1476547660983776
# 	scaled_reward=0.1476547660983776
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17992
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.14769318894053848
# 	scaled_reward=0.14769318894053848
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17991
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.14769318894053848
# 	scaled_reward=0.14769318894053848
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17990
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15032484521624676
# 	scaled_reward=0.15032484521624676
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17989
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15032484521624676
# 	scaled_reward=0.15032484521624676
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17988
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15032484521624676
# 	scaled_reward=0.15032484521624676
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17987
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1503289893524247
# 	scaled_reward=0.1503289893524247
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17986
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15083140011338747
# 	scaled_reward=0.15083140011338747
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17985
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15272634338792943
# 	scaled_reward=0.15272634338792943
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17984
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15272634338792943
# 	scaled_reward=0.15272634338792943
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17983
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15272634338792943
# 	scaled_reward=0.15272634338792943
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17982
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15272634338792943
# 	scaled_reward=0.15272634338792943
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17981
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15380413683631197
# 	scaled_reward=0.15380413683631197
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17980
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.14906552467583636
# 	scaled_reward=0.14906552467583636
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17979
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.14906552467583636
# 	scaled_reward=0.14906552467583636
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17978
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.14906552467583636
# 	scaled_reward=0.14906552467583636
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17977
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15203261403102133
# 	scaled_reward=0.15203261403102133
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17976
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1520496434768975
# 	scaled_reward=0.1520496434768975
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17975
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1526459781836167
# 	scaled_reward=0.1526459781836167
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17974
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15723148406939
# 	scaled_reward=0.15723148406939
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17973
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15723148406939
# 	scaled_reward=0.15723148406939
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17972
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15727750958321668
# 	scaled_reward=0.15727750958321668
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17971
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15727750958321668
# 	scaled_reward=0.15727750958321668
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17970
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15727750958321668
# 	scaled_reward=0.15727750958321668
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17969
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15727750958321668
# 	scaled_reward=0.15727750958321668
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17968
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1577444908353281
# 	scaled_reward=0.1577444908353281
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17967
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1577444908353281
# 	scaled_reward=0.1577444908353281
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17966
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15875629465581542
# 	scaled_reward=0.15875629465581542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17965
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15875629465581542
# 	scaled_reward=0.15875629465581542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17964
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15875629465581542
# 	scaled_reward=0.15875629465581542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17963
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15875629465581542
# 	scaled_reward=0.15875629465581542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17962
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15875629465581542
# 	scaled_reward=0.15875629465581542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17961
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1593813181387608
# 	scaled_reward=0.1593813181387608
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17960
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15938662457334865
# 	scaled_reward=0.15938662457334865
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=17959
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.15938662457334865
# 	scaled_reward=0.15938662457334865
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:#######
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:Currently in episode 0
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:	Epsilon value: 0.8578510257087774
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:	Cumulative reward: -4682030.097053528
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:	Maximum reward: -65.75220489501953
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:	Policy network loss: 0.03622813522815704
# INFO:eptnr.algorithms.deep_rl.deep_q_learning.deep_max_q_learner:#######
#
#   1%|          | 1/128 [03:46<7:59:52, 226.72s/it]INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18053
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10177215847864578
# 	scaled_reward=0.10177215847864578
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18052
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10177215847864578
# 	scaled_reward=0.10177215847864578
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18051
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10177215847864578
# 	scaled_reward=0.10177215847864578
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18050
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10177215847864578
# 	scaled_reward=0.10177215847864578
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18049
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10177215847864578
# 	scaled_reward=0.10177215847864578
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18048
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10193010921551957
# 	scaled_reward=0.10193010921551957
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18047
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10193010921551957
# 	scaled_reward=0.10193010921551957
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18046
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10468450745360175
# 	scaled_reward=0.10468450745360175
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18045
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10468450745360175
# 	scaled_reward=0.10468450745360175
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18044
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10468450745360175
# 	scaled_reward=0.10468450745360175
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18043
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11548212745387255
# 	scaled_reward=0.11548212745387255
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18042
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18041
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18040
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18039
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18038
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18037
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11616132103941122
# 	scaled_reward=0.11616132103941122
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18036
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12202641357698893
# 	scaled_reward=0.12202641357698893
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18035
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.1217919956471542
# 	scaled_reward=0.1217919956471542
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18034
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043148777858546
# 	scaled_reward=0.12043148777858546
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18033
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043148777858546
# 	scaled_reward=0.12043148777858546
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18032
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043184888352351
# 	scaled_reward=0.12043184888352351
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18031
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043184888352351
# 	scaled_reward=0.12043184888352351
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18030
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043184888352351
# 	scaled_reward=0.12043184888352351
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18029
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043184888352351
# 	scaled_reward=0.12043184888352351
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18028
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12043184888352351
# 	scaled_reward=0.12043184888352351
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# ...
# 	n_edges=18048
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18047
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18046
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18045
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18044
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18043
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.10122990823609627
# 	scaled_reward=0.10122990823609627
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18042
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11149397879453023
# 	scaled_reward=0.11149397879453023
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18041
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.11682764638944591
# 	scaled_reward=0.11682764638944591
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18040
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12011048125649205
# 	scaled_reward=0.12011048125649205
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18039
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12011048125649205
# 	scaled_reward=0.12011048125649205
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18038
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12011048125649205
# 	scaled_reward=0.12011048125649205
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18037
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.12011048125649205
# 	scaled_reward=0.12011048125649205
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18036
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13260128343922017
# 	scaled_reward=0.13260128343922017
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18035
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13260128343922017
# 	scaled_reward=0.13260128343922017
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18034
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13400166385213863
# 	scaled_reward=0.13400166385213863
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18033
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18032
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18031
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18030
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18029
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18028
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18027
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18026
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13403824857328062
# 	scaled_reward=0.13403824857328062
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18025
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13605813326449245
# 	scaled_reward=0.13605813326449245
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18024
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13605813326449245
# 	scaled_reward=0.13605813326449245
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18023
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13605813326449245
# 	scaled_reward=0.13605813326449245
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18022
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13605813326449245
# 	scaled_reward=0.13605813326449245
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18021
# 	n_vertices=488
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Resulting rewards:
# 	calculated_reward=0.13605813326449245
# 	scaled_reward=0.13605813326449245
# INFO:/home/rico/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:Received graph with:
# 	n_edges=18054	n_vertices=488Created subgraph:
# 	n_edges=18020
# 	n_vertices=488
#   2%|▏         | 2/128 [08:49<9:15:54, 264.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 max_rewards_over_episodes, epsilon_over_episodes = dmql.train(return_max_rewards_over_episodes=True,
#       2                                                               return_epsilon_over_episodes=True, verbose=True)
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/algorithms/deep_rl/deep_q_learning/deep_max_q_learner.py:43, in DeepMaxQLearner.train(self, return_cum_rewards_over_episodes, return_max_rewards_over_episodes, return_epsilon_over_episodes, verbose)
#      41 epsilon = self.eps_schedule.get_current_eps()
#      42 action_ = self.choose_action(state, epsilon)
# ---> 43 next_state, reward = self.step(state, action_)
#      45 cum_reward += reward.item()
#      46 max_reward = max([reward.item(), max_reward])
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/algorithms/deep_rl/deep_q_learning/abstract_deep_q_learner.py:138, in AbstractDeepQLearner.step(self, state, action)
#     135     g_prime.es[edges]['active'] = 0
#     137     # Evaluate graph
# --> 138     reward = self.reward.evaluate(g_prime)
#     139     reward = torch.tensor([[reward]], device=device, dtype=torch.float)
#     141 except ActionAlreadyTakenError as e:
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/egalitarian.py:91, in EgalitarianTheilAndCostReward.evaluate(self, g, *args, **kwargs)
#      82 def evaluate(self, g: ig.Graph, *args, **kwargs) -> float:
#      83     """
#      84
#      85     Args:
#    (...)
#      89
#      90     """
# ---> 91     theil_reward = self.theil_reward.evaluate(g, *args, **kwargs)
#      93     total_savings = sum(g.es.select(active=0)['cost'])
#      95     partial_theil_reward = self.theil_rg.generate_reward(theil_reward)
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:64, in BaseReward.evaluate(self, g, *args, **kwargs)
#      57 if self.verbose:
#      58     logger.info("Received graph with:\n"
#      59                 f"\tn_edges={len(g.es)}"
#      60                 f"\tn_vertices={len(g.vs)}\n"
#      61                 f"Created subgraph:\n"
#      62                 f"\tn_edges={len(g_prime.es)}\n"
#      63                 f"\tn_vertices={len(g_prime.vs)}")
# ---> 64 calculated_reward = self._evaluate(g_prime, *args, **kwargs)
#      65 if self.reward_scaling:
#      66     scaled_reward = self._reward_scaling(calculated_reward)
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/egalitarian.py:21, in EgalitarianTheilReward._evaluate(self, g, *args, **kwargs)
#      20 def _evaluate(self, g: ig.Graph, *args, **kwargs) -> float:
# ---> 21     metrics_dfs = self.retrieve_dfs(g)
#      23     theil_inequality = {metric: None for metric in self.metrics_names}
#      25     for metric, metric_df in metrics_dfs.items():
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/base_reward.py:31, in BaseReward.retrieve_dfs(self, g)
#      29 def retrieve_dfs(self, g: ig.Graph) -> Dict[str, pd.DataFrame]:
#      30     g_prime = g.subgraph_edges(g.es.select(active_eq=1), delete_vertices=False)
# ---> 31     tt_samples, hops_samples, com_samples = get_tt_hops_com_dfs(g_prime, self.census_data, self.com_threshold)
#      33     metrics_values = {
#      34         TravelMetric.TT.value: tt_samples,
#      35         TravelMetric.HOPS.value: hops_samples,
#      36         TravelMetric.COM.value: com_samples
#      37     }
#      39     metrics_dfs = {metrics_name: metrics_values[metrics_name] for metrics_name in self.metrics_names}
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/utils/graph_computation_utils.py:71, in get_tt_hops_com_dfs(g, census_data, com_threshold)
#      69 value_cols = metric_df.loc[:, metric_df.columns.str.contains('POI')]
#      70 metric_df['average'] = (value_cols < com_threshold).sum(axis=1)
# ---> 71 com_samples = _generate_samples(metric_df[metric_df['metric'] == 'travel_time'], groups_census)
#      73 return tt_samples, hops_samples, com_samples
#
# File ~/Documents/equitable-transport-reduction/eptnr_package/eptnr/rewards/utils/graph_computation_utils.py:53, in _generate_samples(metric_df, inh_per_group)
#      50 labels = np.repeat(group.replace('n_', ''), samples_group.shape[0])
#      51 labels = labels.reshape((-1, 1))
# ---> 53 group_individuals = np.hstack([samples_group, labels])
#      54 df = pd.DataFrame(group_individuals, columns=['metric_value', 'group'])
#      55 city = pd.concat([city, df], axis=0)
#
# File <__array_function__ internals>:180, in hstack(*args, **kwargs)
#
# File ~/anaconda3/envs/equitable-transport-reduction/lib/python3.9/site-packages/numpy/core/shape_base.py:345, in hstack(tup)
#     343     return _nx.concatenate(arrs, 0)
#     344 else:
# --> 345     return _nx.concatenate(arrs, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
